# %%
# Импортирование библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
\
from datetime import datetime, timedelta

# Источники данных
import yfinance as yf
from fredapi import Fred

# %%
access = '7e16fe38faf71392ad4c298e596ab8a7'

# %%
start_date = '2000-01-01'
end_date = datetime.today().strftime("%Y-%m-%d")

# %%
gold = yf.download('GC=F', start=start_date, end=end_date, progress=False, auto_adjust=True)
silver = yf.download('SI=F', start=start_date, end=end_date, progress=False, auto_adjust=True)

# %%
# !pip freeze > requirements.txt
